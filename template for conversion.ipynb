# %%
import pandas as pd

# %%
df = pd.read_csv("tempdf")
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 31.5+ MB

# %%
for i in df.select_dtypes('number').columns.to_list() :
  df[i] = df[i].astype("float32")

for i in df.select_dtypes('object').columns.to_list() :
  df[i] = df[i].astype("category")
  print(i)
# Out:
# Activity

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: category(1), float32(561)
# memory usage: 15.7 MB

# %%
df.to_parquet("human-activity-recognition-with-smartphones_train.parquet",compression="gzip")
